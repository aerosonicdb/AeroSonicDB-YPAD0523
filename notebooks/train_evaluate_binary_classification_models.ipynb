# %%
import os

from aerosonicdb.utils import get_project_root
from aerosonicdb.data import download
from aerosonicdb.features import extract_mfccs, extract_env_mfccs
from aerosonicdb.models.mfcc import logistic_regression, mlp, cnn

# %%
root_path = get_project_root()
dataset_path = os.path.join(root_path, 'data/raw')

# %%
# download the dataset
download(target_path=dataset_path)
# Out:
# Dataset downloaded - see "data/raw" directory

# %%
# extract features for the train set
extract_mfccs.save_mfccs(set_str='train')
# Out:
# train MFCCs extracted.

# %%
# extract features for the test set
extract_mfccs.save_mfccs(set_str='test')
# Out:
# test MFCCs extracted.

# %%
# extract features for the environment set
extract_env_mfccs.extract_all_env_features()
# Out:
# JSON feature descriptor file already exists for environment #1 - not generating features.
# JSON feature descriptor file already exists for environment #2 - not generating features.
# JSON feature descriptor file already exists for environment #3 - not generating features.
# JSON feature descriptor file already exists for environment #4 - not generating features.
# JSON feature descriptor file already exists for environment #5 - not generating features.
# JSON feature descriptor file already exists for environment #6 - not generating features.
# MFCCs extracted.

# %%
# run 5-fold CV with logistic regression, test against Test and Environment and print results
lr_cv, lr_test, lr_env = logistic_regression.run_cv()
# Out:
# Training data loaded.
#
# Running 5-fold cross-validation...
# CV results:
# [0.99418221 0.98868403 0.97665403 0.97573288 0.97704774]
# Average Precision Score for 5-fold CV: 98.25% (0.75%)
#
# Running 5-model evaluation against Test set...
#
# Test data loaded.
# Test evaluation results:
# [np.float64(0.983477416525586), np.float64(0.9903458868633113), np.float64(0.9858446014017763), np.float64(0.9850058796533142), np.float64(0.9862046113966041)]
# Average Precision Score against Test set: 98.62% (0.23%)
#
# Running 5-model evaluation against the Environment set...
#
# Environment test data loaded.
# Environment evaluation results:
# [np.float64(0.8144007048756439), np.float64(0.8721936727800519), np.float64(0.8359990720773771), np.float64(0.8460910473574873), np.float64(0.8041280946691624)]
# Average Precision Score against Environment set: 83.46% (2.40%)

# %%
# run 5-fold CV with MLP, test against Test and Environment and print results
mlp_cv, mlp_test, mlp_env = mlp.run_cv(epochs=50)
# Out:
# Training data loaded.
#
# Running 5-fold cross-validation...
# CV results:
# [0.99502181 0.99555067 0.97947065 0.98215198 0.97191472]
# Average Precision Score for 5-fold CV: 98.48% (0.92%)
#
# Running 5-model evaluation against Test set...
#
# Test data loaded.
# Test evaluation results:
# [np.float64(0.9861199131549288), np.float64(0.9959997679382349), np.float64(0.9866803144477144), np.float64(0.9887186534711505), np.float64(0.9794268181945028)]
# Average Precision Score against Test set: 98.74% (0.53%)
#
# Running 5-model evaluation against the Environment set...
#
# Environment test data loaded.
# Environment evaluation results:
# [np.float64(0.799610969672045), np.float64(0.9113739245667205), np.float64(0.6603986061285891), np.float64(0.7947921316727462), np.float64(0.8821668199501446)]
# Average Precision Score against Environment set: 80.97% (8.74%)

# %%
# run 5-fold CV with CNN, test against Test and Environment and print results
cnn_cv, cnn_test, cnn_env = cnn.run_cv(epochs=50)
# Out:
# Training data loaded.
#
# Running 5-fold cross-validation...
# CV results:
# [0.99857526 0.98476436 0.99269467 0.9865762  0.98872785]
# Average Precision Score for 5-fold CV: 99.03% (0.49%)
#
# Running 5-model evaluation against Test set...
#
# Test data loaded.
# Test evaluation results:
# [np.float64(0.9956096598471524), np.float64(0.9966984932626968), np.float64(0.9947480917486337), np.float64(0.9912759077375495), np.float64(0.994834672759007)]
# Average Precision Score against Test set: 99.46% (0.18%)
#
# Running 5-model evaluation against the Environment set...
#
# Environment test data loaded.
# Environment evaluation results:
# [np.float64(0.8955647203328364), np.float64(0.9306233133443446), np.float64(0.9048980419361073), np.float64(0.8151654525311826), np.float64(0.937878682640467)]
# Average Precision Score against Environment set: 89.68% (4.37%)

# %%
lr_cv
# Out:
# (np.float64(98.2460179628656),
#  np.float64(0.7541945105882673),
#  array([0.99418221, 0.98868403, 0.97665403, 0.97573288, 0.97704774]))

# %%
mlp_cv
# Out:
# (np.float64(98.48219657254256),
#  np.float64(0.9181549648065614),
#  array([0.99502181, 0.99555067, 0.97947065, 0.98215198, 0.97191472]))

# %%
cnn_cv
# Out:
# (np.float64(99.02676696768415),
#  np.float64(0.49232259345071727),
#  array([0.99857526, 0.98476436, 0.99269467, 0.9865762 , 0.98872785]))

# %%
lr_test
# Out:
# (np.float64(98.61756791681185),
#  np.float64(0.2286925183523907),
#  [np.float64(0.983477416525586),
#   np.float64(0.9903458868633113),
#   np.float64(0.9858446014017763),
#   np.float64(0.9850058796533142),
#   np.float64(0.9862046113966041)])

# %%
mlp_test
# Out:
# (np.float64(98.73890934413062),
#  np.float64(0.531831662336798),
#  [np.float64(0.9861199131549288),
#   np.float64(0.9959997679382349),
#   np.float64(0.9866803144477144),
#   np.float64(0.9887186534711505),
#   np.float64(0.9794268181945028)])

# %%
cnn_test
# Out:
# (np.float64(99.46333650710079),
#  np.float64(0.1819016914700664),
#  [np.float64(0.9956096598471524),
#   np.float64(0.9966984932626968),
#   np.float64(0.9947480917486337),
#   np.float64(0.9912759077375495),
#   np.float64(0.994834672759007)])

# %%
lr_env
# Out:
# (np.float64(83.45625183519445),
#  np.float64(2.401594186695992),
#  [np.float64(0.8144007048756439),
#   np.float64(0.8721936727800519),
#   np.float64(0.8359990720773771),
#   np.float64(0.8460910473574873),
#   np.float64(0.8041280946691624)])

# %%
mlp_env
# Out:
# (np.float64(80.9668490398049),
#  np.float64(8.741162537005941),
#  [np.float64(0.799610969672045),
#   np.float64(0.9113739245667205),
#   np.float64(0.6603986061285891),
#   np.float64(0.7947921316727462),
#   np.float64(0.8821668199501446)])

# %%
cnn_env
# Out:
# (np.float64(89.68260421569877),
#  np.float64(4.3732767672741435),
#  [np.float64(0.8955647203328364),
#   np.float64(0.9306233133443446),
#   np.float64(0.9048980419361073),
#   np.float64(0.8151654525311826),
#   np.float64(0.937878682640467)])
